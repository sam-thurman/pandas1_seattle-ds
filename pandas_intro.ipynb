# %% [markdown]
# # Let's Use Pandas!

# %% [markdown]
# ## What is Pandas?
#
# Pandas, as [the Anaconda docs](https://docs.anaconda.com/anaconda/packages/py3.7_osx-64/) tell us, offers us "High-performance, easy-to-use data structures and data analysis tools." It's something like "Excel for Python", but it's quite a bit more powerful.
#
# Let's first import pandas as pd.

# %%
import pandas as pd

# %% [markdown]
# Now read in the heart dataset.
#
# Pandas has many methods for reading different types of files! Note that here we have a .csv file.
#
# Read about this dataset [here](https://www.kaggle.com/ronitf/heart-disease-uci).
#
# Notice the name of the last column!

# %%
heart = pd.read_csv('heart.csv')
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# The output of the `.read_csv()` function is a pandas *DataFrame*, which has a familiar tabaular structure of rows and columns.

# %%
type(heart)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Two main types of pandas objects are the DataFrame and the Series, the latter being in effect a single column––*plus index*––of the former.
#
# But Pandas is built on top of NumPy, and we can always access the NumPy array underlying a DataFrame using `.values`.

# %%
heart.values
# Out:
# array([[63.,  1.,  3., ...,  0.,  1.,  1.],
#        [37.,  1.,  2., ...,  0.,  2.,  1.],
#        [41.,  0.,  1., ...,  0.,  2.,  1.],
#        ...,
#        [68.,  1.,  0., ...,  2.,  3.,  0.],
#        [57.,  1.,  0., ...,  1.,  3.,  0.],
#        [57.,  0.,  1., ...,  1.,  2.,  0.]])

# %% [markdown]
# What does .head( ) do? What do you learn about the dataset by using it here?

# %%
heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# What about .tail( )? What about .info( ) and .describe( )?

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
# age         303 non-null int64
# sex         303 non-null int64
# cp          303 non-null int64
# trestbps    303 non-null int64
# chol        303 non-null int64
# fbs         303 non-null int64
# restecg     303 non-null int64
# thalach     303 non-null int64
# exang       303 non-null int64
# oldpeak     303 non-null float64
# slope       303 non-null int64
# ca          303 non-null int64
# thal        303 non-null int64
# target      303 non-null int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %% [markdown]
# What can we figure out / guess about the different columns?
#
# Let's check the data type of one of our columns:

# %%
heart['target'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# Notice how we can isolate a column of our DataFrame simply by using square brackets together with the name of the column!

# %% [markdown]
# ## Adding to a DataFrame
#
# Here are two rows that our engineer accidentally left out of the .csv file, expressed as a Python dictionary:

# %%
extra_rows = {'age': [40, 30], 'sex': [1, 0], 'cp': [0, 0], 'trestbps': [120, 130],
              'chol': [240, 200],
             'fbs': [0, 0], 'restecg': [1, 0], 'thalach': [120, 122], 'exang': [0, 1],
              'oldpeak': [0.1, 1.0], 'slope': [1, 1], 'ca': [0, 1], 'thal': [2, 3],
              'target': [0, 0]}
extra_rows
# Out:
# {'age': [40, 30],
#  'sex': [1, 0],
#  'cp': [0, 0],
#  'trestbps': [120, 130],
#  'chol': [240, 200],
#  'fbs': [0, 0],
#  'restecg': [1, 0],
#  'thalach': [120, 122],
#  'exang': [0, 1],
#  'oldpeak': [0.1, 1.0],
#  'slope': [1, 1],
#  'ca': [0, 1],
#  'thal': [2, 3],
#  'target': [0, 0]}

# %% [markdown]
# How can we add this to the bottom of our dataset?

# %%
# Let's first turn this into a DataFrame.
# We can use the .from_dict() method.
extra_rows = pd.DataFrame().from_dict(extra_rows)

# %%
# Now we just need to concatenate the two DataFrames together.
# Note the `ignore_index` parameter! We'll set that to True.
heart_augmented = pd.concat(objs=[heart, extra_rows], ignore_index=True)

# %%
# Let's check the end to make sure we were successful!

heart_augmented.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
# 303   40    1   0       120   240    0        1      120      0      0.1
# 304   30    0   0       130   200    0        0      122      1      1.0
#
#      slope  ca  thal  target
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
# 303      1   0     2       0
# 304      1   1     3       0

# %% [markdown]
# How many different values does have slope have? What about sex? And target?

# %%
# .value_counts()
heart_augmented['slope'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 300    1
# 301    1
# 302    1
# 303    1
# 304    1
# Name: slope, Length: 305, dtype: int64>

# %% [markdown]
# Let's add a new column to our dataset called "test". Set all of its values to 0.

# %%
heart_augmented['test'] = 0

# %% [markdown]
# I can also add columns whose values are functions of existing columns.
#
# How could I add a column, called 'twice_age', that is double the age column?

# %%
heart_augmented['twice_age'] = 2 * heart_augmented['age']

# %% [markdown]
# ## Filtering

# %% [markdown]
# We can use filtering techniques to see only certain rows of our data. If we wanted to see only the rows for patients 70 years of age or older, we can simply type:

# %%
heart[heart['age'] >= 70]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 25    71    0   1       160   302    0        1      162      0      0.4
# 60    71    0   2       110   265    1        0      130      0      0.0
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 145   70    1   1       156   245    0        0      143      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 225   70    1   0       145   174    0        1      125      1      2.6
# 234   70    1   0       130   322    0        0      109      0      2.4
# 238   77    1   0       125   304    0        0      162      1      0.0
# 240   70    1   2       160   269    0        1      112      1      2.9
#
#      slope  ca  thal  target
# 25       2   2     2       1
# 60       2   1     2       1
# 129      2   1     2       1
# 144      1   0     2       1
# 145      2   0     2       1
# 151      1   0     2       1
# 225      0   0     3       0
# 234      1   3     2       0
# 238      2   3     2       0
# 240      1   1     3       0

# %% [markdown]
# Use '&' for "and" and '|' for "or".

# %%
# Display the patients who are 70 or over as well as the patients whose
# trestbps score is greater than 170.
heart[(heart['age']>=70) | (heart['trestbps'] > 170)].shape
# Out:
# (19, 14)

# %% [markdown]
# ## .loc( ) and .iloc( )

# %% [markdown]
# We can use .loc( ) to get, say, the first ten values of the age and trestbps columns:

# %%
heart.loc[:9, ['age', 'trestbps']]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %% [markdown]
# .iloc() is used for selecting locations in the DataFrame **by number**:

# %%
heart.iloc[3, 0]
# Out:
# 56

# %%
# How would we get the same slice as just above by using .iloc() instead of .loc()?
heart.iloc[:10, [0, 3]]
# Out:
#    age  trestbps
# 0   63       145
# 1   37       130
# 2   41       130
# 3   56       120
# 4   57       120
# 5   57       140
# 6   56       140
# 7   44       120
# 8   52       172
# 9   57       150

# %% [markdown]
# ## Statistics
#
# I can use methods like `.mean()`, `.min()`, `.max()` to calculate quick statistics.

# %%
print(heart['age'].max())
print(heart['age'].mean())
print(heart['age'].min())
# Out:
# 77
# 54.366336633663366
# 29

# %% [markdown]
# I can also sort the values in a column by using `.sorted_values()`

# %%
heart.sort_values(by='age', ascending=True)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 58    34    1   3       118   182    0        0      174      0      0.0
# 125   34    0   1       118   210    0        1      192      0      0.7
# 239   35    1   0       126   282    0        0      156      1      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 60    71    0   2       110   265    1        0      130      0      0.0
# 151   71    0   0       112   149    0        1      125      0      1.6
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 238   77    1   0       125   304    0        0      162      1      0.0
#
#      slope  ca  thal  target
# 72       2   0     2       1
# 58       2   0     2       1
# 125      2   0     2       1
# 239      2   0     3       0
# 65       2   0     2       1
# ..     ...  ..   ...     ...
# 60       2   1     2       1
# 151      1   0     2       1
# 129      2   1     2       1
# 144      1   0     2       1
# 238      2   3     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Let's find a .csv file online and experiment with it.
#
# I'm going to head to dataportals.org to find a .csv file.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/okfn/dataportals.org/master/data/portals.csv')
df
# Out:
#                                                   name  \
# 0                                            a2gov_org
# 1                             acikveri-sahinbey-bel-tr
# 2                                     africa_open_data
# 3                              ajuntament-de-tarragona
# 4                                ajuntament-de-terassa
# ..                                                 ...
# 587         dados-abertos-prefeitura-de-belo-horizonte
# 588                                state_of_washington
# 589                                state_of_washington
# 590                                state_of_washington
# 591  portal-de-dados-abertos-da-camara-legislativa-...
#
#                                                  title  \
# 0                                  Ann Arbor, Michigan
# 1                      Açık Veri Portali - Test Yayını
# 2                                     Africa Open Data
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 587  Portal de Dados Abertos – Prefeitura de Belo H...
# 588                                         Washington
# 589                                         Washington
# 590                                         Washington
# 591  Portal de Dados Abertos da Câmara Legislativa ...
#
#                                                    url  \
# 0    http://www.a2gov.org/services/data/Pages/defau...
# 1              http://acikveri.sahinbey.bel.tr/dataset
# 2                           http://africaopendata.org/
# 3                       http://opendata.tarragona.cat/
# 4                        http://opendata.terrassa.cat/
# ..                                                 ...
# 587                          https://dados.pbh.gov.br/
# 588                                http://data.wa.gov/
# 589                                  http://geo.wa.gov
# 590                               http://fiscal.wa.gov
# 591                  http://dadosabertos.cl.df.gov.br/
#
#                                                 author  \
# 0                                    City of Ann Arbor
# 1                                             pinardag
# 2                                     Africa Open Data
# 3                              Ajuntament de Tarragona
# 4                                Ajuntament de Terassa
# ..                                                 ...
# 587  Município de Belo Horizonte (City of Belo Hori...
# 588                                State of Washington
# 589                                State of Washington
# 590                                State of Washington
# 591                                                NaN
#
#                                              publisher      issued  \
# 0                                    City of Ann Arbor         NaN
# 1                                 SahinBey Belediyesi   31/01/2015
# 2                                     Africa Open Data         NaN
# 3                              Ajuntament de Tarragona         NaN
# 4                                Ajuntament de Terassa         NaN
# ..                                                 ...         ...
# 587  Município de Belo Horizonte (City of Belo Hori...         NaN
# 588                                State of Washington         NaN
# 589                                State of Washington         NaN
# 590                                State of Washington         NaN
# 591                                                NaN         NaN
#
#     publisher_classification  \
# 0                        NaN
# 1                 Government
# 2                        NaN
# 3                 Government
# 4                 Government
# ..                       ...
# 587               Government
# 588               Government
# 589               Government
# 590               Government
# 591               Government
#
#                                            description  \
# 0          City of Ann Arbor's Open Data Catalog (USA)
# 1        The first official open data portal of Turkey
# 2    Africa's largest central repository for Govern...
# 3                                  Open Data Tarragona
# 4                                    Open Data Terassa
# ..                                                 ...
# 587  Open data portal of the city of Belo Horizonte...
# 588        Public Open Data of the State of Washington
# 589  Geospatial open data from the State of Washington
# 590           Fiscal open data for state of Washington
# 591  Open Data portal of the local parliament of th...
#
#                             tags license_id  ...                       place  \
# 0              ctic unitedstates        NaN  ...         Ann Arbor, Michigan
# 1                turkey national    Unknown  ...            Gaziantep,Turkey
# 2                    ckan africa        NaN  ...                      Africa
# 3                     city spain        NaN  ...                   Tarragona
# 4                     city spain        NaN  ...                     Terrasa
# ..                           ...        ...  ...                         ...
# 587  local-government,br-MG,CKAN        NaN  ...  Belo Horizonte, MG, Brazil
# 588            ctic unitedstates        NaN  ...   Washington, United States
# 589                 unitedstates        NaN  ...   Washington, United States
# 590         finance unitedstates        NaN  ...   Washington, United States
# 591       local-government,br-DF        NaN  ...                  DF, Brazil
#
#                    location country  language  status  \
# 0    42.2681569,-83.7312291      US        en  active
# 1      37.0587715,37.380137      TR        tr  active
# 2      2.0000003,15.9999997      AF        en  active
# 3           41.1157, 1.2496      ES  ca es en  active
# 4           41.5611, 2.0081      ES     es en  active
# ..                      ...     ...       ...     ...
# 587      -19.9233, -43.9453      BR        pt  active
# 588  47.034922, -122.895756      US        en  active
# 589  47.034922, -122.895756      US        en  active
# 590  47.034922, -122.895756      US        en  active
# 591                     NaN      BR        pt  active
#
#               metadatacreated    generator                    api_endpoint  \
# 0    2011-06-27T18:12:57.439Z          NaN                    Not apparent
# 1                         NaN          NaN                             NaN
# 2    2013-03-15T07:17:26.251Z  CKAN: 2.1.3  http://africaopendata.org/api/
# 3                         NaN          NaN                             NaN
# 4                         NaN          NaN                             NaN
# ..                        ...          ...                             ...
# 587      2019-06-03T15:40:44Z         CKAN  https://dados.pbh.gov.br/api/3
# 588  2011-06-27T18:16:05.479Z          NaN                             NaN
# 589                       NaN          NaN                             NaN
# 590                       NaN          NaN                             NaN
# 591      2019-09-23T14:22:38Z          NaN                             NaN
#
#                          api_type full_metadata_download
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ..                            ...                    ...
# 587                      CKAN API                    NaN
# 588  Socrata Open Data API (SODA)                    NaN
# 589           Esri ArcGIS Online                     NaN
# 590                           NaN                    NaN
# 591                           NaN                    NaN
#
# [592 rows x 21 columns]

# %% [markdown]
# ## Your turn!
